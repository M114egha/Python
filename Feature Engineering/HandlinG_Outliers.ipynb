# %% [markdown]
# ### Box plot

# %%
import  numpy as np

# %%
lst_marks=[23,67,23,67,87,12,56,56,87,45,32,6,76,90,21]

# %%
min,q1,median,q3,max=np.quantile(lst_marks,[0 , 0.25 ,0.50 , 0.75 , 1.0])

# %%
min,q1,median,q3,max
# Out:
# (6.0, 23.0, 56.0, 71.5, 90.0)

# %%
import seaborn as sns
sns.boxplot(lst_marks)
# Out:
# c:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
lst_marks=[-94 , 1,561 ,23,67,23,67,87,12,56,56,87,45,32,6,76,90,21, 123]

# %%
sns.boxplot(lst_marks)
# Out:
# c:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>
